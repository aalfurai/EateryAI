# %% [markdown]
# # Meal Combination Sandbox
# _Disclaimer: This code is not final, but just an exploration. The storage and data structures used are simply for the purpose of this notebook._

# %% [markdown]
# ## Load Data

# %%
import json
import pandas as pd

with open('../restaurants.menu_item_variations.json', 'r') as file:
    item_list = json.load(file)
file.close()

# %% [markdown]
# ## Select all Items for Specific Restaurants: Chick-fil-A, Taco Bell, and Chipotle

# %%
chick_fil_a_items = []
tacobell_items = []
chipotle_items = []

for item in item_list:
    if item.get("restaurant_name") == "Chick-fil-A":
        chick_fil_a_items.append(item)

    elif item.get("restaurant_name") == "Taco Bell":
        tacobell_items.append(item)
    
    elif item.get("restaurant_name") == "Chipotle":
        chipotle_items.append(item)

print(f"Number of Chick-fil-A items: {len(chick_fil_a_items)}")
print(f"Number of Taco Bell items: {len(tacobell_items)}")
print(f"Number of Chipotle items: {len(chipotle_items)}")

# making dataframes just to visualize easier
df_cfa = pd.DataFrame(chick_fil_a_items)
df_tb = pd.DataFrame(tacobell_items)
df_chipotle = pd.DataFrame(chipotle_items)
# Out:
# Number of Chick-fil-A items: 177
# Number of Taco Bell items: 205
# Number of Chipotle items: 99

# %%
# extract nutrition information as columns
def extract_nutrition(df):
    nutrition_df = df["nutrition_info"].apply(pd.Series)
    df = pd.concat([df.drop(columns=["nutrition_info"]), nutrition_df], axis=1)
    return df

df_cfa = extract_nutrition(df_cfa)
df_tb = extract_nutrition(df_tb)
df_chipotle = extract_nutrition(df_chipotle)

# %% [markdown]
# ### Visualization

# %%
# Chick fil A items
df_cfa.head()
# Out:
#                        item_id                           menu_item_id  \
# 0   chick_fil_a_chick_n_strips  item_818528ff980240e39250845e28b061f7
# 1  chick_fil_a_chicken_nuggets  item_44dbe341c1dd40f095ad04f1bced08e9
# 2  chick_fil_a_chicken_nuggets  item_44dbe341c1dd40f095ad04f1bced08e9
# 3  chick_fil_a_chicken_nuggets  item_44dbe341c1dd40f095ad04f1bced08e9
# 4   chick_fil_a_chick_n_strips  item_818528ff980240e39250845e28b061f7
#
#     menu_item_name restaurant_name                     cuisine_type  \
# 0   Chick-n-Strips     Chick-fil-A  [American, Fast Food, Southern]
# 1  Chicken Nuggets     Chick-fil-A  [American, Fast Food, Southern]
# 2  Chicken Nuggets     Chick-fil-A  [American, Fast Food, Southern]
# 3  Chicken Nuggets     Chick-fil-A  [American, Fast Food, Southern]
# 4   Chick-n-Strips     Chick-fil-A  [American, Fast Food, Southern]
#
#                                macronutrient_profile recipe_items  price  \
# 0  [High Protein, Low Carb, Low Calorie, High Sod...           {}   4.29
# 1    [Low Carb, Low Calorie, High Sodium, Low Sugar]           {}   3.49
# 2  [High Protein, Low Carb, Low Calorie, High Sod...           {}   4.99
# 3  [High Protein, Low Carb, High Calorie, High So...           {}  14.99
# 4             [High Protein, High Sodium, Low Sugar]           {}   6.99
#
#    golden_ratio                                     ai_description  ...  \
# 0         0.950  Enjoy tender, hand-breaded Chick-n-Strips, per...  ...
# 1         1.000  Deliciously crispy, bite-sized chicken nuggets...  ...
# 2         1.080  Deliciously crispy, bite-sized chicken nuggets...  ...
# 3         1.062  Deliciously crispy, bite-sized chicken nuggets...  ...
# 4         0.951  Enjoy tender, hand-breaded Chick-n-Strips, per...  ...
#
#   serving_size calories cholesterol sodium  total_carbohydrates  \
# 0     2 strips      200          50    580                   11
# 1    4 nuggets      130          40    610                    5
# 2    8 nuggets      250          85   1210                   11
# 3   30 nuggets      970         285   3660                   35
# 4     4 strips      410         100   1150                   22
#
#    dietary_fiber  sugars  protein  potassium  total_fat
# 0              0       1       19          0          9
# 1              0       0       13          0          6
# 2              0       1       27          0         11
# 3              4       1      103          0         46
# 4              0       2       39          0         19
#
# [5 rows x 23 columns]

# %%
# Taco Bell items
df_tb.head()
# Out:
#                                item_id                           menu_item_id  \
# 0               taco_bell_bean_burrito  item_bc872feac0cd4c038de6a4bc27b91eef
# 1      taco_bell_beefy_5_layer_burrito  item_68a8b72cef0e4ac9acf2b3cb8445ef23
# 2    taco_bell_burrito_supreme_chicken  item_d8bbc465a2ff443f99500235a73971c9
# 3  taco_bell_chicken_enchilada_burrito  item_2185ad40296c41209c67ba5496401929
# 4        taco_bell_coffee_with_creamer  item_1aaeafaf9be14badb5ce82fcd2e2aaaa
#
#               menu_item_name restaurant_name                    cuisine_type  \
# 0               Bean Burrito       Taco Bell  [Mexican, American, Fast Food]
# 1      Beefy 5-Layer Burrito       Taco Bell  [Mexican, American, Fast Food]
# 2  Burrito Supreme - Chicken       Taco Bell  [Mexican, American, Fast Food]
# 3  Chicken Enchilada Burrito       Taco Bell  [Mexican, American, Fast Food]
# 4        Coffee with Creamer       Taco Bell  [Mexican, American, Fast Food]
#
#                               macronutrient_profile recipe_items  price  \
# 0  [High Carb, Low Calorie, High Sodium, Low Sugar]           {}   1.29
# 1                          [High Sodium, Low Sugar]           {}   2.99
# 2                          [High Sodium, Low Sugar]           {}   3.99
# 3                          [High Sodium, Low Sugar]           {}   3.99
# 4    [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   2.49
#
#    golden_ratio                                     ai_description  ...  \
# 0         0.371  Savor the hearty blend of seasoned refried bea...  ...
# 1         0.367  Indulge in a hearty Beefy 5-Layer Burrito, pac...  ...
# 2         0.514  Savor the Burrito Supreme filled with tender c...  ...
# 3         0.500  Savor the bold flavors of our Chicken Enchilad...  ...
# 4         0.667  Savor the smooth blend of rich coffee and crea...  ...
#
#   serving_size calories cholesterol sodium  total_carbohydrates  \
# 0    1 burrito      350           5   1000                   54
# 1    1 burrito      490          30   1250                   63
# 2    1 burrito      370          35   1110                   49
# 3    1 burrito      380          40   1150                   49
# 4     1 coffee       30           0      0                    3
#
#    dietary_fiber  sugars  protein  potassium  total_fat
# 0             11       3       13          0          9
# 1              9       5       18          0         18
# 2              8       4       19          0         11
# 3              3       3       19          0         12
# 4              0       3        2          0          2
#
# [5 rows x 23 columns]

# %%
# chipotle items
df_chipotle.head()
# Out:
#                                    item_id  \
# 0  chipotle_izze_sparkling_blackberry_soda
# 1       chipotle_tractor_hibiscus_lemonade
# 2            chipotle_chicken_burrito_bowl
# 3                     chipotle_black_beans
# 4                chipotle_carnitas_burrito
#
#                             menu_item_id                  menu_item_name  \
# 0  item_09007bf4a7904846a73f8438b299f460  Izze Sparkling Blackberry Soda
# 1  item_86b8d873b6f840e4822df75ba6baac51       Tractor Hibiscus Lemonade
# 2  item_66a6aa38b02d47208ed7141199aec1e1            Chicken Burrito Bowl
# 3  item_1c084543ac7b4259873ac1bf141574e9                     Black Beans
# 4  item_7d30d25697de4ecdaab8169d37d5e74a                Carnitas Burrito
#
#   restaurant_name                        cuisine_type  \
# 0        Chipotle  [Mexican, Latin American, Tex-Mex]
# 1        Chipotle  [Mexican, Latin American, Tex-Mex]
# 2        Chipotle  [Mexican, Latin American, Tex-Mex]
# 3        Chipotle  [Mexican, Latin American, Tex-Mex]
# 4        Chipotle  [Mexican, Latin American, Tex-Mex]
#
#                               macronutrient_profile recipe_items  price  \
# 0   [High Carb, Low Calorie, Low Sodium, Low Sugar]           {}   2.50
# 1   [High Carb, Low Calorie, Low Sodium, Low Sugar]           {}   3.50
# 2  [High Protein, Low Carb, Low Calorie, Low Sugar]           {}   8.50
# 3               [High Carb, Low Calorie, Low Sugar]           {}   2.50
# 4  [High Protein, High Sodium, Low Sugar, Balanced]           {}   9.75
#
#    golden_ratio                                     ai_description  ...  \
# 0         0.000  Delight in the effervescent zing of Izze Spark...  ...
# 1         0.000  Quench your thirst with this refreshing hibisc...  ...
# 2         1.684  Savor a hearty Chicken Burrito Bowl, featuring...  ...
# 3         0.583  Savor our hearty black beans, perfectly season...  ...
# 4         0.708  Savor the tender, slow-cooked carnitas wrapped...  ...
#
#   serving_size calories cholesterol sodium  total_carbohydrates  \
# 0     1 bottle      170           0     35                   41
# 1        22 oz      150           0      0                   36
# 2         4 oz      190         115    370                    1
# 3         4 oz      120           0    250                   23
# 4         4 oz      480          70   1210                   45
#
#    dietary_fiber  sugars  protein  potassium  total_fat
# 0              0      39        0          0          0
# 1              0      35        0          0          0
# 2              0       1       32          0          7
# 3             11       0        7          0          1
# 4              2       0       34          0         17
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Categories
#
# Display all categories for Chick-fil-A, Taco Bell, and Chipotle.

# %%
cfa_categories = df_cfa['category'].unique()
tb_categories = df_tb['category'].unique()
chip_categories = df_chipotle['category'].unique()

print(f"Chick fil A categories: {cfa_categories}")
print(f"Taco Bell categories: {tb_categories}")
print(f"Chipotle categories: {chip_categories}")
# Out:
# Chick fil A categories: ['Classic Chicken' 'Beverages' 'Breakfast' 'Desserts' "Kid's Meal"
#  'Salad Dressings' 'Cool Wraps' 'Sauces' 'Sides' 'Salads']
# Taco Bell categories: ['Burritos' 'Beverages' 'Tacos' 'Breakfast' 'Cantina Chicken'
#  'Condiments & Sauces' 'Chalupas' 'Nachos' 'Sides' 'Specialties']
# Chipotle categories: ['Beverages' 'Burrito Bowls' 'Extras and Toppings' 'Burritos'
#  'Quesadillas' 'Salads' 'Tacos' 'Lifestyle Bowls' 'Tortilla Chips']

# %% [markdown]
# ## Exploring Data

# %% [markdown]
# Checking the content of some categories to distinguish what meal component they may be. (Feel free to explore yourself)

# %% [markdown]
# ### Chick-fil-A Data

# %%
'''Chick fil A categories: ['Classic Chicken' 'Beverages' 'Breakfast' 'Desserts' "Kid's Meal"
 'Salad Dressings' 'Cool Wraps' 'Sauces' 'Sides' 'Salads']'''

cfa_cat_name = "Breakfast"
display(df_cfa.loc[df_cfa['category'] == cfa_cat_name])
# Out:
#                                               item_id  \
# 53            chick_fil_a_hash_brown_scramble_burrito
# 55               chick_fil_a_bacon_egg_cheese_biscuit
# 57                        chick_fil_a_chicken_biscuit
# 58          chick_fil_a_yogurt_parfait_w_cookie_cumbs
# 60              chick_fil_a_egg_cheese_english_muffin
# 61            chick_fil_a_hash_brown_scramble_burrito
# 62  chick_fil_a_yogurt_parfait_with_harvest_nut_gr...
# 65                        chick_fil_a_egg_white_grill
# 66               chick_fil_a_hash_brown_scramble_bowl
# 67             chick_fil_a_chicken_egg_cheese_biscuit
# 68              chick_fil_a_egg_cheese_english_muffin
# 70               chick_fil_a_hash_brown_scramble_bowl
# 71         chick_fil_a_sausage_egg_and_cheese_biscuit
# 74                   chick_fil_a_hot_buttered_biscuit
# 76                          chick_fil_a_chick_n_minis
# 79                          chick_fil_a_chick_n_minis
# 80               chick_fil_a_hash_brown_scramble_bowl
# 81            chick_fil_a_hash_brown_scramble_burrito
# 82            chick_fil_a_hash_brown_scramble_burrito
# 86                          chick_fil_a_chick_n_minis
# 87              chick_fil_a_chicken_egg_cheese_muffin
# 88                         chick_fil_a_english_muffin
# 89               chick_fil_a_hash_brown_scramble_bowl
# 90                            chick_fil_a_hash_browns
# 92                  chick_fil_a_spicy_chicken_biscuit
#
#                              menu_item_id  \
# 53  item_57b571666c3e48fc8f253bb0e65e1315
# 55  item_4113c01c405f4ec5ac415e8ffa67c34d
# 57  item_8c359b035e514162add9db3dfcca12c7
# 58  item_696737d778b34b2caf288baebc324099
# 60  item_07042d87afd04700973507580773663d
# 61  item_57b571666c3e48fc8f253bb0e65e1315
# 62  item_440d8ca23c2b4ecfa16ddc71e9c0d1aa
# 65  item_403c6de25b2845a0b3804449be646e8a
# 66  item_cd3d9826a6cd40e58b2bd0eaf8a084df
# 67  item_be2be90336df444faa0fc92fe6768944
# 68  item_07042d87afd04700973507580773663d
# 70  item_cd3d9826a6cd40e58b2bd0eaf8a084df
# 71  item_b10274268e6548108b9d1b1058b026e3
# 74  item_80103285c8bc4f86881e8e077169afe1
# 76  item_66c20fcaff8644dfa4e339fe9772a52c
# 79  item_66c20fcaff8644dfa4e339fe9772a52c
# 80  item_cd3d9826a6cd40e58b2bd0eaf8a084df
# 81  item_57b571666c3e48fc8f253bb0e65e1315
# 82  item_57b571666c3e48fc8f253bb0e65e1315
# 86  item_66c20fcaff8644dfa4e339fe9772a52c
# 87  item_a7c5d7c2c4d34bb1b9d1d6172662fd79
# 88  item_563cef2dab0c4a04a3b41560ab98967a
# 89  item_cd3d9826a6cd40e58b2bd0eaf8a084df
# 90  item_0589871236764832a5e65428d0048eac
# 92  item_b0056ed759974de0ae0ef93c4bc18032
#
#                              menu_item_name restaurant_name  \
# 53              Hash Brown Scramble Burrito     Chick-fil-A
# 55              Bacon, Egg & Cheese Biscuit     Chick-fil-A
# 57                          Chicken Biscuit     Chick-fil-A
# 58           Yogurt Parfait w/ Cookie Cumbs     Chick-fil-A
# 60              Egg & Cheese English Muffin     Chick-fil-A
# 61              Hash Brown Scramble Burrito     Chick-fil-A
# 62  Yogurt Parfait with Harvest Nut Granola     Chick-fil-A
# 65                          Egg White Grill     Chick-fil-A
# 66                 Hash Brown Scramble Bowl     Chick-fil-A
# 67            Chicken, Egg & Cheese Biscuit     Chick-fil-A
# 68              Egg & Cheese English Muffin     Chick-fil-A
# 70                 Hash Brown Scramble Bowl     Chick-fil-A
# 71           Sausage Egg and Cheese Biscuit     Chick-fil-A
# 74                     Hot Buttered Biscuit     Chick-fil-A
# 76                            Chick-n-Minis     Chick-fil-A
# 79                            Chick-n-Minis     Chick-fil-A
# 80                 Hash Brown Scramble Bowl     Chick-fil-A
# 81              Hash Brown Scramble Burrito     Chick-fil-A
# 82              Hash Brown Scramble Burrito     Chick-fil-A
# 86                            Chick-n-Minis     Chick-fil-A
# 87            Chicken, Egg, & Cheese Muffin     Chick-fil-A
# 88                           English Muffin     Chick-fil-A
# 89                 Hash Brown Scramble Bowl     Chick-fil-A
# 90                              Hash Browns     Chick-fil-A
# 92                    Spicy Chicken Biscuit     Chick-fil-A
#
#                        cuisine_type  \
# 53  [American, Fast Food, Southern]
# 55  [American, Fast Food, Southern]
# 57  [American, Fast Food, Southern]
# 58  [American, Fast Food, Southern]
# 60  [American, Fast Food, Southern]
# 61  [American, Fast Food, Southern]
# 62  [American, Fast Food, Southern]
# 65  [American, Fast Food, Southern]
# 66  [American, Fast Food, Southern]
# 67  [American, Fast Food, Southern]
# 68  [American, Fast Food, Southern]
# 70  [American, Fast Food, Southern]
# 71  [American, Fast Food, Southern]
# 74  [American, Fast Food, Southern]
# 76  [American, Fast Food, Southern]
# 79  [American, Fast Food, Southern]
# 80  [American, Fast Food, Southern]
# 81  [American, Fast Food, Southern]
# 82  [American, Fast Food, Southern]
# 86  [American, Fast Food, Southern]
# 87  [American, Fast Food, Southern]
# 88  [American, Fast Food, Southern]
# 89  [American, Fast Food, Southern]
# 90  [American, Fast Food, Southern]
# 92  [American, Fast Food, Southern]
#
#                                 macronutrient_profile recipe_items  price  \
# 53  [High Protein, High Fat, High Calorie, High So...           {}   4.99
# 55                           [High Sodium, Low Sugar]           {}   3.99
# 57                           [High Sodium, Low Sugar]           {}   3.99
# 58               [Low Calorie, Low Sodium, Low Sugar]           {}   4.99
# 60              [Low Calorie, High Sodium, Low Sugar]           {}   3.99
# 61  [High Protein, High Fat, High Calorie, High So...           {}   4.99
# 62               [Low Calorie, Low Sodium, Low Sugar]           {}   4.99
# 65  [High Protein, Low Calorie, High Sodium, Low S...           {}   4.99
# 66  [High Protein, Low Carb, High Fat, High Sodium...           {}   6.99
# 67             [High Protein, High Sodium, Low Sugar]           {}   4.99
# 68                 [High Fat, High Sodium, Low Sugar]           {}   4.99
# 70       [Low Carb, High Fat, High Sodium, Low Sugar]           {}   5.99
# 71                 [High Fat, High Sodium, Low Sugar]           {}   3.99
# 74  [Low Protein, Low Calorie, High Sodium, Low Su...           {}   2.49
# 76              [Low Calorie, High Sodium, Low Sugar]           {}   3.99
# 79  [High Protein, High Calorie, High Sodium, Low ...           {}  14.99
# 80  [High Protein, Low Carb, High Fat, High Sodium...           {}   6.99
# 81                                                 []           {}   4.99
# 82             [High Protein, High Sodium, Low Sugar]           {}   6.99
# 86                 [High Sodium, Low Sugar, Balanced]           {}   4.29
# 87             [High Protein, High Sodium, Low Sugar]           {}   4.99
# 88    [High Carb, Low Calorie, Low Sodium, Low Sugar]           {}   2.49
# 89  [High Protein, Low Carb, High Fat, High Sodium...           {}   6.99
# 90    [Low Protein, High Fat, Low Calorie, Low Sugar]           {}   2.99
# 92                           [High Sodium, Low Sugar]           {}   4.99
#
#     golden_ratio                                     ai_description  ...  \
# 53         0.486  Savor a hearty breakfast with our Hash Brown S...  ...
# 55         0.357  Start your day right with a flaky, buttery bis...  ...
# 57         0.413  Start your day with a flaky buttermilk biscuit...  ...
# 58         0.480  Indulge in a creamy yogurt parfait layered wit...  ...
# 60         0.533  Start your day with a fluffy egg and melted ch...  ...
# 61         0.394  Savor a hearty breakfast with our Hash Brown S...  ...
# 62         0.464  Start your day with a delightful blend of crea...  ...
# 65         0.862  Start your day with our Egg White Grill, featu...  ...
# 66         0.617  Savor the hearty Hash Brown Scramble Bowl, fea...  ...
# 67         0.491  Start your day with a flaky biscuit layered wi...  ...
# 68         0.462  Start your day with a fluffy egg and melted ch...  ...
# 70         0.479  Savor the hearty Hash Brown Scramble Bowl, fea...  ...
# 71         0.365  Indulge in a flaky buttermilk biscuit layered ...  ...
# 74         0.138  Indulge in our flaky, warm Hot Buttered Biscui...  ...
# 76         0.571  Delight in a warm, fluffy biscuit filled with ...  ...
# 79         0.552  Delight in a warm, fluffy biscuit filled with ...  ...
# 80         0.732  Savor the hearty Hash Brown Scramble Bowl, fea...  ...
# 81         0.000  Savor a hearty breakfast with our Hash Brown S...  ...
# 82         0.538  Savor a hearty breakfast with our Hash Brown S...  ...
# 86         0.568  Delight in a warm, fluffy biscuit filled with ...  ...
# 87         0.643  Start your day with a savory Chicken, Egg, & C...  ...
# 88         0.357  Start your day right with a warm, toasted Engl...  ...
# 89         0.609  Savor the hearty Hash Brown Scramble Bowl, fea...  ...
# 90         0.111  Delightfully crispy and golden, our Hash Brown...  ...
# 92         0.395  Start your day with a spicy, crispy chicken fi...  ...
#
#         serving_size calories cholesterol sodium  total_carbohydrates  \
# 53         1 burrito      700         415   1750                   51
# 55         1 biscuit      420         180   1290                   38
# 57         1 biscuit      460          45   1510                   45
# 58         1 parfait      250          15     85                   33
# 60        1 sandwich      300         180    800                   29
# 61         1 burrito      710         395   1440                   46
# 62         1 parfait      280          15     85                   37
# 65        1 sandwich      290          60    970                   29
# 66            1 bowl      470         415   1340                   19
# 67              206g      530         215   1830                   45
# 68        1 sandwich      520         210   1060                   30
# 70            1 bowl      480         395   1010                   15
# 71         1 biscuit      630         210   1540                   38
# 74         1 biscuit      290           0    760                   37
# 76               94g      280          40    650                   30
# 79        10 sliders      870         130   2150                   92
# 80            1 bowl      410         415   1190                   15
# 81         1 serving        0           0      0                    0
# 82         1 burrito      650         415   1620                   46
# 86              126g      370          50    870                   41
# 87              190g      420         215   1350                   37
# 88  1 English muffin      140           0    220                   29
# 89            1 bowl      460         405   1360                   19
# 90               77g      270           0    440                   23
# 92              145g      430          30   1300                   43
#
#     dietary_fiber  sugars  protein  potassium  total_fat
# 53              3       2       34          0         40
# 55              2       4       15          0         23
# 57              2       6       19          0         23
# 58              1      26       12          0          8
# 60              1       2       16          0         14
# 61              3       1       28          0         46
# 62              1      27       13          0          8
# 65              1       2       25          0          8
# 66              2       2       29          0         30
# 67              2       7       26          0         27
# 68              1       2       24          0         34
# 70              2       1       23          0         37
# 71              2       4       23          0         43
# 74              2       4        4          0         15
# 76              1       5       16          0         10
# 79              5      14       48          0         35
# 80              2       2       30          0         26
# 81              0       0        0          0          0
# 82              3       2       35          0         36
# 86              2       7       21          0         14
# 87              1       4       27          0         19
# 88              1       1        5          0          2
# 89              2       2       28          0         30
# 90              3       0        3          0         18
# 92              2       5       17          0         21
#
# [25 rows x 23 columns]

# %% [markdown]
# ### Taco Bell Data

# %%
'''Taco Bell categories: ['Burritos' 'Beverages' 'Tacos' 'Breakfast' 'Cantina Chicken'
 'Condiments & Sauces' 'Chalupas' 'Nachos' 'Sides' 'Specialties']'''

tb_cat_name = "Condiments & Sauces"
display(df_tb.loc[df_tb['category'] == tb_cat_name])
# Out:
#                                   item_id  \
# 129                  taco_bell_mild_sauce
# 131             taco_bell_breakfast_salsa
# 132        taco_bell_nugget_dipping_sauce
# 133           taco_bell_pepper_jack_sauce
# 134       taco_bell_premium_guacamole_dip
# 136       taco_bell_creamy_jalapeno_sauce
# 137                   taco_bell_red_sauce
# 138  taco_bell_reduced_fat_sour_cream_dip
# 139                       taco_bell_salsa
# 142                   taco_bell_hot_sauce
# 143        taco_bell_nugget_dipping_sauce
# 145                taco_bell_diablo_sauce
# 146                 taco_bell_salsa_verde
# 149           taco_bell_cilantro_dressing
# 150       taco_bell_green_tomatillo_sauce
# 151                   taco_bell_guacamole
# 152        taco_bell_nugget_dipping_sauce
# 156               taco_bell_pico_de_gallo
# 157                   taco_bell_salsa_dip
# 158      taco_bell_reduced_fat_sour_cream
# 161                  taco_bell_fire_sauce
# 167             taco_bell_spicy_ranch_dip
# 168            taco_bell_nacho_cheese_dip
# 169                 taco_bell_pizza_sauce
#
#                               menu_item_id              menu_item_name  \
# 129  item_b1a34e10fe684507b6e87b1a29dc95e6                  Mild Sauce
# 131  item_ee95089c94294d589ac6839024ae4ecb             Breakfast Salsa
# 132  item_2ebeb298d6cc4d98b88fc6ad8a9db7dc        Nugget Dipping Sauce
# 133  item_b076a600c6584b8f9234c6f9a40d9780           Pepper Jack Sauce
# 134  item_57756f900d064b1c8acc474e942926d8       Premium Guacamole Dip
# 136  item_21f4680809bf4371bb5548cc92c355ad       Creamy Jalapeno Sauce
# 137  item_25816abada984710ad3583e845c86afb                   Red Sauce
# 138  item_550942d163114ef9b28c00a7059833cf  Reduced-Fat Sour Cream Dip
# 139  item_de49ee06b6754e869f52d8121a22a6c8                       Salsa
# 142  item_d485a1a5657a47d9b7d8b9be477d9a0b                   Hot Sauce
# 143  item_2ebeb298d6cc4d98b88fc6ad8a9db7dc        Nugget Dipping Sauce
# 145  item_89e18e63e25242a78c7bbb6a8670e02f                Diablo Sauce
# 146  item_b53e9d3fe55d416d84f42e910db685ce                 Salsa Verde
# 149  item_f65327221b254042b242e76fd96045e4           Cilantro Dressing
# 150  item_5a84f49c2b2048009b73e4875fc13443       Green Tomatillo Sauce
# 151  item_3673039a1d96483fa6bafd1219f8a2a5                   Guacamole
# 152  item_2ebeb298d6cc4d98b88fc6ad8a9db7dc        Nugget Dipping Sauce
# 156  item_224b6c9b78004f0195c008c797cd9ae9               Pico de Gallo
# 157  item_845c7684c2ab4c758dad9635386cb1f3                   Salsa Dip
# 158  item_10f9e73cfcab46b0b6a6a8c349dafbce      Reduced Fat Sour Cream
# 161  item_f0d2b6bd85e644c180f213f736f88dab                  Fire Sauce
# 167  item_7e8438a5632c4accaf0a34184bf3de7b             Spicy Ranch Dip
# 168  item_90e6b83a5351467a89d238d4761ac5a2            Nacho Cheese Dip
# 169  item_173cbf2ddce147b180cfea34697b6cb1                 Pizza Sauce
#
#     restaurant_name                    cuisine_type  \
# 129       Taco Bell  [Mexican, American, Fast Food]
# 131       Taco Bell  [Mexican, American, Fast Food]
# 132       Taco Bell  [Mexican, American, Fast Food]
# 133       Taco Bell  [Mexican, American, Fast Food]
# 134       Taco Bell  [Mexican, American, Fast Food]
# 136       Taco Bell  [Mexican, American, Fast Food]
# 137       Taco Bell  [Mexican, American, Fast Food]
# 138       Taco Bell  [Mexican, American, Fast Food]
# 139       Taco Bell  [Mexican, American, Fast Food]
# 142       Taco Bell  [Mexican, American, Fast Food]
# 143       Taco Bell  [Mexican, American, Fast Food]
# 145       Taco Bell  [Mexican, American, Fast Food]
# 146       Taco Bell  [Mexican, American, Fast Food]
# 149       Taco Bell  [Mexican, American, Fast Food]
# 150       Taco Bell  [Mexican, American, Fast Food]
# 151       Taco Bell  [Mexican, American, Fast Food]
# 152       Taco Bell  [Mexican, American, Fast Food]
# 156       Taco Bell  [Mexican, American, Fast Food]
# 157       Taco Bell  [Mexican, American, Fast Food]
# 158       Taco Bell  [Mexican, American, Fast Food]
# 161       Taco Bell  [Mexican, American, Fast Food]
# 167       Taco Bell  [Mexican, American, Fast Food]
# 168       Taco Bell  [Mexican, American, Fast Food]
# 169       Taco Bell  [Mexican, American, Fast Food]
#
#                                  macronutrient_profile recipe_items  price  \
# 129                                                 []           {}   1.00
# 131     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.00
# 132  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.00
# 133  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.00
# 134  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.49
# 136  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.00
# 137     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.00
# 138  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.49
# 139     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.00
# 142                                                 []           {}   1.00
# 143  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.00
# 145                                                 []           {}   1.00
# 146     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.00
# 149  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.00
# 150     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.00
# 151  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.49
# 152  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.00
# 156     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.29
# 157     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.49
# 158  [Low Carb, High Fat, Low Calorie, Low Sodium, ...           {}   1.00
# 161                                                 []           {}   1.00
# 167  [Low Carb, High Fat, Low Calorie, Low Sugar, K...           {}   1.49
# 168  [Low Carb, High Fat, Low Calorie, Low Sugar, K...           {}   1.49
# 169     [Low Carb, Low Calorie, Low Sodium, Low Sugar]           {}   1.00
#
#      golden_ratio                                     ai_description  ...  \
# 129         0.000  Add a zesty kick to your meal with Taco Bell's...  ...
# 131         0.000  Elevate your breakfast with Taco Bell's zesty ...  ...
# 132         0.000  Delightfully creamy and savory, this rich nugg...  ...
# 133         0.000  Spice up your meal with our zesty Pepper Jack ...  ...
# 134         0.143  Savor the creamy, fresh taste of our Premium G...  ...
# 136         0.000  Elevate your meal with our luscious creamy jal...  ...
# 137         0.000  Elevate your meal with Taco Bell's zesty Red S...  ...
# 138         0.167  Indulge guilt-free in our Reduced-Fat Sour Cre...  ...
# 139         0.000  Zesty and vibrant, our fresh salsa bursts with...  ...
# 142         0.000  Elevate your meal with Taco Bell's zesty Hot S...  ...
# 143         0.000  Delightfully creamy and savory, this rich nugg...  ...
# 145         0.000  Experience the fiery kick of Diablo Sauce, a b...  ...
# 146         0.000  Bright and zesty Salsa Verde bursts with fresh...  ...
# 149         0.000  Zesty cilantro dressing brings a burst of vibr...  ...
# 150         0.000  Zesty green tomatillo sauce bursts with vibran...  ...
# 151         0.000  Smooth, creamy guacamole made from ripe avocad...  ...
# 152         0.000  Delightfully creamy and savory, this rich nugg...  ...
# 156         0.000  Zesty pico de gallo featuring diced tomatoes, ...  ...
# 157         0.000  Zesty and vibrant, our Salsa Dip blends ripe t...  ...
# 158         0.333  Creamy and tangy reduced fat sour cream adds a...  ...
# 161         0.000  Add a fiery kick to your meal with this bold, ...  ...
# 167         0.043  Indulge in this creamy, zesty dip infused with...  ...
# 168         0.600  Indulge in our creamy Nacho Cheese Dip, a velv...  ...
# 169         0.000  Zesty and vibrant, our pizza sauce delivers a ...  ...
#
#     serving_size calories cholesterol sodium  total_carbohydrates  \
# 129     1 packet        0           0     30                    0
# 131     1 packet        0           0     50                    1
# 132       1.5 oz      200           5    160                    8
# 133          14g       70           5     50                    1
# 134          43g       70           0    210                    3
# 136          14g       70           0     50                    1
# 137          28g       10           0    170                    2
# 138          43g       60          10     45                    4
# 139          21g        5           0     80                    1
# 142     1 packet        0           0     45                    0
# 143       1.5 oz      210          10    210                    5
# 145     1 packet        0           0     30                    0
# 146           6g        5           0     55                    1
# 149          28g       90          10    210                    2
# 150          28g       10           0    170                    2
# 151          21g       35           0    105                    2
# 152       1.5 oz      210          15    200                    3
# 156          21g        5           0     35                    1
# 157          43g       10           0    220                    2
# 158          21g       30           5     20                    2
# 161     1 packet        0           0     55                    0
# 167          43g      230          20    280                    2
# 168          40g      150          35    250                    2
# 169          28g       10           0     80                    2
#
#      dietary_fiber  sugars  protein  potassium  total_fat
# 129              0       0        0          0          0
# 131              0       0        0          0          0
# 132              0       7        0          0         19
# 133              0       0        0          0          7
# 134              2       0        1          0          6
# 136              0       1        0          0          7
# 137              0       0        0          0          0
# 138              0       2        1          0          4
# 139              0       1        0          0          0
# 142              0       0        0          0          0
# 143              1       4        0         60         21
# 145              0       0        0          0          0
# 146              0       0        0          0          0
# 149              0       0        0          0          9
# 150              0       1        0          0          0
# 151              1       0        0          0          3
# 152              0       1        0          2         22
# 156              0       1        0          0          0
# 157              0       1        0          0          0
# 158              0       1        1          0          2
# 161              0       0        0          0          0
# 167              0       2        1          0         24
# 168              1       0        9          0         12
# 169              0       1        0          0          0
#
# [24 rows x 23 columns]

# %% [markdown]
# ### Chipotle Data

# %%
'''Chipotle categories: ['Beverages' 'Burrito Bowls' 'Extras and Toppings' 'Burritos'
 'Quesadillas' 'Salads' 'Tacos' 'Lifestyle Bowls' 'Tortilla Chips']'''

chip_cat_name = "Burrito Bowls"
display(df_chipotle.loc[df_chipotle['category'] == chip_cat_name])
# Out:
#                                       item_id  \
# 2               chipotle_chicken_burrito_bowl
# 13             chipotle_carnitas_burrito_bowl
# 16             chipotle_sofritas_burrito_bowl
# 26  chipotle_plant_based_chorizo_burrito_bowl
# 30             chipotle_barbacoa_burrito_bowl
# 34          chipotle_carne_asada_burrito_bowl
# 38                chipotle_steak_burrito_bowl
#
#                              menu_item_id                    menu_item_name  \
# 2   item_66a6aa38b02d47208ed7141199aec1e1              Chicken Burrito Bowl
# 13  item_fd10bd13d53e4e8bac079cce1f0e5241             Carnitas Burrito Bowl
# 16  item_fd57cee6af6a41398259e3fdc845250f             Sofritas Burrito Bowl
# 26  item_fd40403bbb2249ee9778ca1b23418fea  Plant Based Chorizo Burrito Bowl
# 30  item_e74b9bbd0a054a80bf7b3a4d09d01213             Barbacoa Burrito Bowl
# 34  item_648ecf06e0a5471ea24f7ed7a08b0c40          Carne Asada Burrito Bowl
# 38  item_68f66e0f17e44a94948d5a826296a40d                Steak Burrito Bowl
#
#    restaurant_name                        cuisine_type  \
# 2         Chipotle  [Mexican, Latin American, Tex-Mex]
# 13        Chipotle  [Mexican, Latin American, Tex-Mex]
# 16        Chipotle  [Mexican, Latin American, Tex-Mex]
# 26        Chipotle  [Mexican, Latin American, Tex-Mex]
# 30        Chipotle  [Mexican, Latin American, Tex-Mex]
# 34        Chipotle  [Mexican, Latin American, Tex-Mex]
# 38        Chipotle  [Mexican, Latin American, Tex-Mex]
#
#                                 macronutrient_profile recipe_items  price  \
# 2    [High Protein, Low Carb, Low Calorie, Low Sugar]           {}   8.50
# 13  [High Protein, Low Carb, Low Calorie, High Sod...           {}   8.75
# 16  [Low Carb, High Fat, Low Calorie, High Sodium,...           {}   7.50
# 26    [Low Carb, Low Calorie, High Sodium, Low Sugar]           {}  10.50
# 30  [High Protein, Low Carb, Low Calorie, High Sod...           {}   9.50
# 34  [High Protein, Low Carb, High Fat, Low Calorie...           {}  10.50
# 38   [High Protein, Low Carb, Low Calorie, Low Sugar]           {}   8.50
#
#     golden_ratio                                     ai_description  ...  \
# 2          1.684  Savor a hearty Chicken Burrito Bowl, featuring...  ...
# 13         1.421  Savor the tender, slow-cooked carnitas nestled...  ...
# 16         0.552  Savor the robust flavor of our Sofritas Burrit...  ...
# 26         0.727  Savor the bold flavors of our Plant Based Chor...  ...
# 30         1.412  Savor the tender, shredded barbacoa beef in a ...  ...
# 34         1.160  Savor the bold flavors of marinated carne asad...  ...
# 38         1.579  Savor the bold flavors of tender, marinated st...  ...
#
#    serving_size calories cholesterol sodium  total_carbohydrates  \
# 2          4 oz      190         115    370                    1
# 13         4 oz      190          70    540                    1
# 16         4 oz      145           0    555                    9
# 26       1 bowl      220           0    690                   16
# 30         4 oz      170          60    510                    2
# 34       1 bowl      250          90    740                    1
# 38         4 oz      190          65    320                    2
#
#     dietary_fiber  sugars  protein  potassium  total_fat
# 2               0       1       32          0          7
# 13              0       0       27          0          8
# 16              4       5        8          0         10
# 26              6       1       16          0          8
# 30              0       1       24          0          7
# 34              0       0       29          0         14
# 38              0       1       30          0          7
#
# [7 rows x 23 columns]

# %%
# looking at nutrition info for each item to get a better feel for what is in it
# e.g. Chicken Burrito Bowl
print(f"Chicken Burrito Bowl description: {df_chipotle.loc[2, 'ai_description']}")
print(f"Protein: {df_chipotle.loc[2, 'protein']}")
print(f"Calories: {df_chipotle.loc[2, 'calories']}")

# e.g. Carnitas Burrito Bowl
print(f"Carnitas Burrito Bowl description: {df_chipotle.loc[13, 'ai_description']}")
print(f"Protein: {df_chipotle.loc[13, 'protein']}")
print(f"Calories: {df_chipotle.loc[13, 'calories']}")

# e.g. Chicken Quesadilla
print(f"Chicken Quesadilla Protein: {df_chipotle.loc[43, 'protein']}")
print(f"Calories: {df_chipotle.loc[43, 'calories']}")
# Out:
# Chicken Burrito Bowl description: Savor a hearty Chicken Burrito Bowl, featuring tender grilled chicken, zesty cilantro-lime rice, fresh salsas, and protein-packed black beans for a satisfying meal.
# Protein: 32
# Calories: 190
# Carnitas Burrito Bowl description: Savor the tender, slow-cooked carnitas nestled atop a vibrant bed of cilantro-lime rice, black beans, and zesty toppings for a protein-packed delight.
# Protein: 27
# Calories: 190
# Chicken Quesadilla Protein: 58
# Calories: 830

# %% [markdown]
# Breaking down contents of items in Chipotle:
# - Looking at the calorie count for a "Burrito Bowl" and referencing the online Chipotle menu, each item appears to only account for the protein itself. The item does not contain any rice, beans, or other add-ons yet.
# - Similarly, "Burritos" are most likely just the protein + tortilla. I assume other categories follow a similar pattern.
# - "Lifestyle Bowls" are pre-made and complete bowls.
# - sidenote: all "Tacos" have a serving size of 3.

# %% [markdown]
# ### Some Thoughts After Exploring Data
#
# Issue 1: broader categories like "Kid's Meal" and "Breakfast" in Chick fil A contain items that may be from different categories.
# - I'm just going to hard code the differences for this example
#     - most items in "Breakfast" category can probably be an "Entree" (with the exception of hash browns)
#     - items in the "Kid's Meal" are an entree if they have the word "meal" in the name, "milk" for beverage, and the rest would be sides
#
# Issue 2: when computing combinations in the future, should we try to account for 'realistic' combinations?
# - If you order a salad, you would probably want salad dressing to go with it. Blindly assigning meals + sides/add-ons won't always be 'realistic'
# - Most likely, you wouldn't want to have salad dressing as an add-on when you ordered a chicken sandwich.
#
# Issue 3: "Build-your-own" restaurants (Chipotle) don't exactly map to the 5 categories
# - Possible idea: rather than starting off as an "Entree", each item could instead be labeled as a "Base." A "Base" might require that certain conditions are met before it becomes an "Entree." However, this might be hard to generalize:
#     - For example, a Burrito Bowl isn't a bowl yet if it contains only protein.
#     - A Burrito is basically still a Taco (tortilla + protein) until you add more toppings.
#     - However, a user could possibly be satisfied with a Taco being purely tortilla + protein.

# %% [markdown]
# ## Assign Meal Categories (Entree, Side, Drink, Dessert, Add-on)
# Note: this is hard-coded just to have categories to work with.
#
# ### Chick-fil-A

# %%
# add a column for meal categories
df_cfa['meal_category'] = 'temp'

# assign meal categories
# note: hard-coded assignment

cfa_entree_categories = ['Classic Chicken', 'Breakfast', 'Cool Wraps', 'Salads', ]
df_cfa.loc[df_cfa['category'].isin(cfa_entree_categories), 'meal_category'] = 'Entree'

df_cfa.loc[df_cfa['category'] == 'Sides', 'meal_category'] = 'Side'

df_cfa.loc[df_cfa['category'] == 'Beverages', 'meal_category'] = 'Drink'

df_cfa.loc[df_cfa['category'] == 'Desserts', 'meal_category'] = 'Dessert'

addon_categories = ['Salad Dressings', 'Sauces']
df_cfa.loc[df_cfa['category'].isin(addon_categories), 'meal_category'] = 'Add-on'

# assigning some categories manually
df_cfa.loc[90, 'meal_category'] = 'Side' # hash brown

kid_mask = df_cfa['category'] == "Kid's Meal"
df_cfa.loc[kid_mask & df_cfa['menu_item_name'].str.contains('Meal', case=False, na=False),'meal_category'] = 'Entree'
df_cfa.loc[kid_mask & df_cfa['menu_item_name'].str.contains('Milk', case=False, na=False),'meal_category'] = 'Drink'
df_cfa.loc[kid_mask & ~df_cfa['menu_item_name'].str.contains('Meal|Milk', case=False, na=False),'meal_category'] = 'Side'

# %%
# check that all items got assigned a category
display(df_cfa.loc[df_cfa['meal_category'] == 'temp'])
# Out:
# Empty DataFrame
# Columns: [item_id, menu_item_id, menu_item_name, restaurant_name, cuisine_type, macronutrient_profile, recipe_items, price, golden_ratio, ai_description, category, allergen_info, menu_card_image, serving_size, calories, cholesterol, sodium, total_carbohydrates, dietary_fiber, sugars, protein, potassium, total_fat, meal_category]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Sorting the menu items for CFA by category:

# %%
cfa_entrees = df_cfa.loc[df_cfa['meal_category'] == 'Entree'].copy()
cfa_sides = df_cfa.loc[df_cfa['meal_category'] == 'Side'].copy()
cfa_drinks = df_cfa.loc[df_cfa['meal_category'] == 'Drink'].copy()
cfa_desserts = df_cfa.loc[df_cfa['meal_category'] == 'Dessert'].copy()
cfa_addons = df_cfa.loc[df_cfa['meal_category'] == 'Add-on'].copy()

print(f"Count of Entrees: {len(cfa_entrees)}")
print(f"Count of Sides: {len(cfa_sides)}")
print(f"Count of Drinks: {len(cfa_drinks)}")
print(f"Count of Desserts: {len(cfa_desserts)}")
print(f"Count of Add-Ons: {len(cfa_addons)}")
# Out:
# Count of Entrees: 76
# Count of Sides: 19
# Count of Drinks: 43
# Count of Desserts: 24
# Count of Add-Ons: 15

# %% [markdown]
# ### Taco Bell
#
# Items of concern:
# - Cheesy roll up in 'Specialties': not sufficient to be an entree
# - Cinnabon Delights (2, 4, and 12 pc): I will put in "Dessert" for now

# %%
# add a column for meal categories
df_tb['meal_category'] = 'temp'

tb_entree_categories = ['Burritos', 'Tacos', 'Breakfast', 'Cantina Chicken','Chalupas', 'Nachos', 'Specialties']
df_tb.loc[df_tb['category'].isin(tb_entree_categories), 'meal_category'] = 'Entree'

df_tb.loc[df_tb['category'] == 'Sides', 'meal_category'] = 'Side'

df_tb.loc[df_tb['category'] == 'Beverages', 'meal_category'] = 'Drink'

df_tb.loc[df_tb['category'] == "Condiments & Sauces", 'meal_category'] = 'Add-on'

# manual assignments
df_tb.loc[91, 'meal_category'] = 'Side'     # hash brown
df_tb.loc[194, 'meal_category'] = 'Side'    # cheesy roll up
df_tb.loc[df_tb['menu_item_name'] == "Cinnabon Delights", 'meal_category'] = 'Dessert'

# %%
# check that all items got assigned a category
display(df_tb.loc[df_tb['meal_category'] == 'temp'])
# Out:
# Empty DataFrame
# Columns: [item_id, menu_item_id, menu_item_name, restaurant_name, cuisine_type, macronutrient_profile, recipe_items, price, golden_ratio, ai_description, category, allergen_info, menu_card_image, serving_size, calories, cholesterol, sodium, total_carbohydrates, dietary_fiber, sugars, protein, potassium, total_fat, meal_category]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Sorting the menu items for Taco Bell by category:

# %%
tb_entrees = df_tb.loc[df_tb['meal_category'] == 'Entree'].copy()
tb_sides = df_tb.loc[df_tb['meal_category'] == 'Side'].copy()
tb_drinks = df_tb.loc[df_tb['meal_category'] == 'Drink'].copy()
tb_desserts = df_tb.loc[df_tb['meal_category'] == 'Dessert'].copy()
tb_addons = df_tb.loc[df_tb['meal_category'] == 'Add-on'].copy()

print(f"Count of Entrees: {len(tb_entrees)}")
print(f"Count of Sides: {len(tb_sides)}")
print(f"Count of Drinks: {len(tb_drinks)}")
print(f"Count of Desserts: {len(tb_desserts)}")
print(f"Count of Add-Ons: {len(tb_addons)}")
# Out:
# Count of Entrees: 75
# Count of Sides: 16
# Count of Drinks: 87
# Count of Desserts: 3
# Count of Add-Ons: 24

# %% [markdown]
# ### Chipotle: TBD

# %% [markdown]
# ## Meal Combination Exploration
#
# Information to calculate when storing meals:
# - calories
# - protein
# - price

# %% [markdown]
# ### Chick-fil-A
#
# Naive approach: precompute all meals

# %%
import itertools

# %%
# forcing the combo to at least have Entree, Side, and Drink
def compute_all_cfa_combos(addons=False, desssert=False):
    categories = [cfa_entrees, cfa_sides, cfa_drinks]
    
    if addons:
        categories.append(cfa_addons)
    
    if desssert:
        categories.append(cfa_desserts)
    
    combinations = itertools.product(*categories)
    return combinations     # returns an iterator object

# %%
iter_cfa_combo_basic = compute_all_cfa_combos()
list_cfa_combo_basic = list(iter_cfa_combo_basic)
print(f"Number of total combinations for Entree + Side + Drink combo: {len(list_cfa_combo_basic)}")

iter_cfa_combo_extra = compute_all_cfa_combos(addons=True, desssert=True)
list_cfa_combo_extra = list(iter_cfa_combo_extra)
print(f"Number of total combinations for Entree, Side, Drink, Dessert and Add-On combo: {len(list_cfa_combo_extra)}")
# Out:
# Number of total combinations for Entree + Side + Drink combo: 62092
# Number of total combinations for Entree, Side, Drink, Dessert and Add-On combo: 22353120

# %% [markdown]
# ## Meal Combination Storage and Computation Ideas
#
# 1. Knapsack Approach
#     - 0/1 Knapsack problem:
#
#         _"Given two arrays, `profit[]` and `weight[]`, where each element represents the profit and weight of an item respectively, also given an integer `W` representing the maximum capacity of the knapsack (the total weight it can hold)._
#
#         _Put the items into the knapsack such that the sum of profits associated with them is the maximum possible, without exceeding the capacity W."_
#
#         (https://www.geeksforgeeks.org/dsa/0-1-knapsack-problem-dp-10/)
#     - Concern:
#         - Knapsack tries to maximize a single value from a pool of items and returns a best solution. We want to hit targets (protein, calories, price) without losing structure to meals (maintain rules with categories).
#         - We want to have multiple top picks and rank results. We would have to adjust knapsack to give best k results.
#         - Overall, knapsack on its own may not be sufficient for meal building. However, it may have a use when trying to maximize leftover calories.
#
# 2. Meal Precomputation
#     - Storing every single meal combination is inefficient
#     - Recomputing every single meal after a user request is also inefficient
#     - Another note: allowing for multiple entrees (maybe max 2-3) can allow for goals to be hit quicker.
#     - Architecture idea:
#         1. Precompute entree combinations. Store UID, item IDs, protein total, calorie total, price total
#         2. Filter dynamically after user interaction. Use boolen masking/vectorization (quick) to filter for acceptable protein, price, and calorie ranges.
#         3. Add on optional sides or drinks (add-ons can come in later).
#         4. Apply scoring algorithm.
#     - Expansion: add some sort of caching mechanism for common presets
#
#     - Edits to this approach: _all_ entree combinations may also explode as system grows. We can possibly filter down "unreasonable" combinations to reduce storage.

# %% [markdown]
# ### Entree Precomputation
# It is useful to adjust the storage of the entrees before calculating their combinations.

# %%
cfa_entrees_dict = cfa_entrees[["menu_item_id", "menu_item_name", "price", "calories", "protein"]].to_dict("records")

# %%
# these are based on the filters within Eatery
MAX_PRICE = 100.0
MAX_CALORIES = 3000   
MAX_PROTEIN = 150


def calculate_entree_combos(entrees, max_count=2):
    entree_combos = []
    combo_id = 1    # change id numbering later, maybe

    for k in range(1, max_count+1):
        for combo in itertools.combinations_with_replacement(entrees, k):
            # calculate totals
            total_price = sum(item['price'] for item in combo)
            total_calories = sum(item['calories'] for item in combo)
            total_protein = sum(item['protein'] for item in combo)


            if total_price > MAX_PRICE:
                continue
            if total_calories > MAX_CALORIES:
                continue
            if total_price > MAX_PRICE:
                continue

            entree_combos.append({
                "combo_id": combo_id,
                "entree_ids": tuple(item['menu_item_id'] for item in combo),
                "entree_names": tuple(item['menu_item_name'] for item in combo),
                "n_entrees": k,
                "price": total_price,
                "calories": total_calories,
                "protein": total_protein
            })

            combo_id += 1
    
    return pd.DataFrame(entree_combos)

# %%
def display_entree_combo(row_entry):
    print(f"Combo ID is {row_entry['combo_id']}")
    print(f"There are {row_entry['n_entrees']} entrees in this combo: {row_entry['entree_names']}")
    print(f"Total price is: {row_entry['price']}")
    print(f"Total calories are: {row_entry['calories']}")
    print(f"Total protein is: {row_entry['protein']}")

# %% [markdown]
# Testing the computation on Chick-fil-A:

# %%
cfa_entree_combos = calculate_entree_combos(cfa_entrees_dict)

# %%
display(cfa_entree_combos)
# Out:
#       combo_id                                         entree_ids  \
# 0            1           (item_818528ff980240e39250845e28b061f7,)
# 1            2           (item_44dbe341c1dd40f095ad04f1bced08e9,)
# 2            3           (item_44dbe341c1dd40f095ad04f1bced08e9,)
# 3            4           (item_44dbe341c1dd40f095ad04f1bced08e9,)
# 4            5           (item_818528ff980240e39250845e28b061f7,)
# ...        ...                                                ...
# 2997      2998  (item_e89cf65042ea4351b512ff6e2ea37e5e, item_e...
# 2998      2999  (item_e89cf65042ea4351b512ff6e2ea37e5e, item_e...
# 2999      3000  (item_e89cf65042ea4351b512ff6e2ea37e5e, item_e...
# 3000      3001  (item_e89cf65042ea4351b512ff6e2ea37e5e, item_e...
# 3001      3002  (item_e89cf65042ea4351b512ff6e2ea37e5e, item_e...
#
#                                         entree_names  n_entrees  price  \
# 0                                  (Chick-n-Strips,)          1   4.29
# 1                                 (Chicken Nuggets,)          1   3.49
# 2                                 (Chicken Nuggets,)          1   4.99
# 3                                 (Chicken Nuggets,)          1  14.99
# 4                                  (Chick-n-Strips,)          1   6.99
# ...                                              ...        ...    ...
# 2997  (Spicy Southwest Salad, Spicy Southwest Salad)          2  21.98
# 2998  (Spicy Southwest Salad, Spicy Southwest Salad)          2  21.98
# 2999  (Spicy Southwest Salad, Spicy Southwest Salad)          2  21.98
# 3000  (Spicy Southwest Salad, Spicy Southwest Salad)          2  21.98
# 3001  (Spicy Southwest Salad, Spicy Southwest Salad)          2  21.98
#
#       calories  protein
# 0          200       19
# 1          130       13
# 2          250       27
# 3          970      103
# 4          410       39
# ...        ...      ...
# 2997      1080       80
# 2998      1250       84
# 2999       960       78
# 3000      1130       82
# 3001      1300       86
#
# [3002 rows x 7 columns]

# %% [markdown]
# Display a few combinations from Chick-fil-A:

# %%
display_entree_combo(cfa_entree_combos.loc[0])
display_entree_combo(cfa_entree_combos.loc[1000])
display_entree_combo(cfa_entree_combos.loc[2900])
# Out:
# Combo ID is 1
# There are 1 entrees in this combo: ('Chick-n-Strips',)
# Total price is: 4.29
# Total calories are: 200
# Total protein is: 19
# Combo ID is 1001
# There are 2 entrees in this combo: ('Smokehouse BBQ Bacon Sandwich', 'Hash Brown Scramble Burrito')
# Total price is: 11.98
# Total calories are: 1300
# Total protein is: 71
# Combo ID is 2901
# There are 2 entrees in this combo: ('Market Salad', 'Spicy Southwest Salad')
# Total price is: 20.98
# Total calories are: 770
# Total protein is: 62

# %% [markdown]
# Some notes:
# - This is still not accounting for variations of an item. For example, this blind combination will combine a 4pc nugget with a 8pc nugget.
